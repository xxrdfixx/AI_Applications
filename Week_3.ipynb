# %% [markdown]
# <a href="https://colab.research.google.com/github/xxrdfixx/AI_Applications/blob/main/Week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.random.seed(3) # To make repeatable
LEARNING_RATE = 0.1
index_list = [0, 1, 2] # Used to randomize order
# Define training examples.

x_train = [np.array([1.0, -1.0, -1.0]),
           np.array([1.0, 1.0, -1.0]),
           np.array([1.0, 1.0, 1.0])]
y_train = [0.0, 1.0, 1.0, 0.0] # Output (ground truth)

def neuron_w(input_count):
    weights = np.zeros(input_count+1)
    for i in range(1,(input_count+1)):
        weights[i] = np.random.uniform(-1.0, 1.0)
    return weights

n_w = [neuron_w(2), neuron_w(2), neuron_w(2)]
n_y = [0, 0, 0]
n_error = [0, 0, 0]

def show_learning():
    print('Current weights:')
    for i, w in enumerate(n_w):
        print('neuron ', i, ': w0 =', '%5.2f' % w[0],', w1 =', '%5.2f' % w[1], ', w2 =','%5.2f' % w[2])
    print('----------------')

def forward_pass(x):
    global n_y
    n_y[0] = np.tanh(np.dot(n_w[0], x)) # Neuron 0
    n_y[1] = np.tanh(np.dot(n_w[1], x)) # Neuron 1
    n2_inputs = np.array([1.0, n_y[0], n_y[1]]) # 1.0 is bias
    z2 = np.dot(n_w[2], n2_inputs)
    n_y[2] = 1.0 / (1.0 + np.exp(-z2))

def backward_pass(y_truth):
    global n_error
    error_prime = -(y_truth - n_y[2])  # Derivative of loss-func
    derivative = n_y[2] * (1.0 - n_y[2])  # Logistic derivative
    n_error[2] = error_prime * derivative
    derivative = 1.0 - n_y[0] ** 2  # tanh derivative
    n_error[0] = n_w[2][1] * n_error[2] * derivative
    derivative = 1.0 - n_y[1] ** 2  # tanh derivative
    n_error[1] = n_w[2][2] * n_error[2] * derivative

def adjust_weights(x):
    global n_w
    n_w[0] -= (x * LEARNING_RATE * n_error[0])
    n_w[1] -= (x * LEARNING_RATE * n_error[1])
    n2_inputs = np.array([1.0, n_y[0], n_y[1]])  # 1.0 is bias
    n_w[2] -= (n2_inputs * LEARNING_RATE * n_error[2])

# Network training Loop

all_correct = False
while not all_correct: # Train until converged
    all_correct = True
    np.random.shuffle(index_list) #randomize order
    for i in index_list: #train on all examples
        forward_pass(x_train[i])
        backward_pass(y_train[i])
        adjust_weights(x_train[i])
        show_learning() #show updated weights
    for i in range(len(x_train)): #check if converged
        forward_pass(x_train[i])
        print('x1 =','%4.1f'%x_train[i][1],',x2 = ','%4.1f'%x_train[i][2], ',y = ','%.4f'%n_y[2])
        if (((y_train[i] < 0.5) and (n_y[2] >= 0.5 )) or ((y_train[i] >= 0.5) and (n_y[2] < 0.5))):
            all_correct = False
# Out:
# Current weights:
# neuron  0 : w0 = -0.01 , w1 =  0.11 , w2 =  0.42
# neuron  1 : w0 = -0.01 , w1 = -0.41 , w2 =  0.03
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 =  0.79
# ----------------
# Current weights:
# neuron  0 : w0 = -0.00 , w1 =  0.12 , w2 =  0.43
# neuron  1 : w0 = -0.00 , w1 = -0.40 , w2 =  0.04
# neuron  2 : w0 = -0.00 , w1 =  0.80 , w2 =  0.78
# ----------------
# Current weights:
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 =  0.42
# neuron  1 : w0 =  0.01 , w1 = -0.39 , w2 =  0.03
# neuron  2 : w0 =  0.01 , w1 =  0.79 , w2 =  0.78
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4759
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.3760
# x1 =  1.0 ,x2 =   1.0 ,y =  0.5378
# Current weights:
# neuron  0 : w0 =  0.00 , w1 =  0.13 , w2 =  0.43
# neuron  1 : w0 =  0.00 , w1 = -0.38 , w2 =  0.04
# neuron  2 : w0 =  0.00 , w1 =  0.80 , w2 =  0.77
# ----------------
# Current weights:
# neuron  0 : w0 =  0.01 , w1 =  0.14 , w2 =  0.43
# neuron  1 : w0 =  0.01 , w1 = -0.38 , w2 =  0.04
# neuron  2 : w0 =  0.01 , w1 =  0.80 , w2 =  0.77
# ----------------
# Current weights:
# neuron  0 : w0 =  0.02 , w1 =  0.15 , w2 =  0.42
# neuron  1 : w0 =  0.02 , w1 = -0.37 , w2 =  0.03
# neuron  2 : w0 =  0.03 , w1 =  0.80 , w2 =  0.76
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4709
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.3903
# x1 =  1.0 ,x2 =   1.0 ,y =  0.5560
# Current weights:
# neuron  0 : w0 =  0.03 , w1 =  0.16 , w2 =  0.43
# neuron  1 : w0 =  0.03 , w1 = -0.36 , w2 =  0.04
# neuron  2 : w0 =  0.04 , w1 =  0.81 , w2 =  0.76
# ----------------
# Current weights:
# neuron  0 : w0 =  0.02 , w1 =  0.16 , w2 =  0.44
# neuron  1 : w0 =  0.02 , w1 = -0.35 , w2 =  0.05
# neuron  2 : w0 =  0.03 , w1 =  0.81 , w2 =  0.76
# ----------------
# Current weights:
# neuron  0 : w0 =  0.03 , w1 =  0.18 , w2 =  0.43
# neuron  1 : w0 =  0.03 , w1 = -0.34 , w2 =  0.04
# neuron  2 : w0 =  0.04 , w1 =  0.81 , w2 =  0.75
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4662
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4046
# x1 =  1.0 ,x2 =   1.0 ,y =  0.5734
# Current weights:
# neuron  0 : w0 =  0.02 , w1 =  0.18 , w2 =  0.43
# neuron  1 : w0 =  0.02 , w1 = -0.33 , w2 =  0.05
# neuron  2 : w0 =  0.03 , w1 =  0.81 , w2 =  0.75
# ----------------
# Current weights:
# neuron  0 : w0 =  0.04 , w1 =  0.19 , w2 =  0.42
# neuron  1 : w0 =  0.03 , w1 = -0.32 , w2 =  0.04
# neuron  2 : w0 =  0.05 , w1 =  0.81 , w2 =  0.74
# ----------------
# Current weights:
# neuron  0 : w0 =  0.04 , w1 =  0.20 , w2 =  0.43
# neuron  1 : w0 =  0.04 , w1 = -0.32 , w2 =  0.05
# neuron  2 : w0 =  0.06 , w1 =  0.82 , w2 =  0.74
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4617
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4187
# x1 =  1.0 ,x2 =   1.0 ,y =  0.5897
# Current weights:
# neuron  0 : w0 =  0.03 , w1 =  0.21 , w2 =  0.43
# neuron  1 : w0 =  0.03 , w1 = -0.31 , w2 =  0.05
# neuron  2 : w0 =  0.04 , w1 =  0.82 , w2 =  0.74
# ----------------
# Current weights:
# neuron  0 : w0 =  0.04 , w1 =  0.21 , w2 =  0.44
# neuron  1 : w0 =  0.04 , w1 = -0.30 , w2 =  0.06
# neuron  2 : w0 =  0.05 , w1 =  0.83 , w2 =  0.73
# ----------------
# Current weights:
# neuron  0 : w0 =  0.05 , w1 =  0.22 , w2 =  0.43
# neuron  1 : w0 =  0.05 , w1 = -0.29 , w2 =  0.05
# neuron  2 : w0 =  0.07 , w1 =  0.83 , w2 =  0.73
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4573
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4330
# x1 =  1.0 ,x2 =   1.0 ,y =  0.6053
# Current weights:
# neuron  0 : w0 =  0.06 , w1 =  0.23 , w2 =  0.43
# neuron  1 : w0 =  0.05 , w1 = -0.29 , w2 =  0.06
# neuron  2 : w0 =  0.08 , w1 =  0.83 , w2 =  0.73
# ----------------
# Current weights:
# neuron  0 : w0 =  0.05 , w1 =  0.23 , w2 =  0.44
# neuron  1 : w0 =  0.04 , w1 = -0.28 , w2 =  0.07
# neuron  2 : w0 =  0.07 , w1 =  0.84 , w2 =  0.72
# ----------------
# Current weights:
# neuron  0 : w0 =  0.06 , w1 =  0.25 , w2 =  0.43
# neuron  1 : w0 =  0.05 , w1 = -0.27 , w2 =  0.06
# neuron  2 : w0 =  0.08 , w1 =  0.84 , w2 =  0.72
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4530
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4472
# x1 =  1.0 ,x2 =   1.0 ,y =  0.6201
# Current weights:
# neuron  0 : w0 =  0.07 , w1 =  0.25 , w2 =  0.43
# neuron  1 : w0 =  0.06 , w1 = -0.26 , w2 =  0.06
# neuron  2 : w0 =  0.09 , w1 =  0.84 , w2 =  0.72
# ----------------
# Current weights:
# neuron  0 : w0 =  0.06 , w1 =  0.26 , w2 =  0.44
# neuron  1 : w0 =  0.05 , w1 = -0.26 , w2 =  0.07
# neuron  2 : w0 =  0.08 , w1 =  0.85 , w2 =  0.72
# ----------------
# Current weights:
# neuron  0 : w0 =  0.07 , w1 =  0.27 , w2 =  0.43
# neuron  1 : w0 =  0.06 , w1 = -0.25 , w2 =  0.06
# neuron  2 : w0 =  0.09 , w1 =  0.85 , w2 =  0.71
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4488
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4613
# x1 =  1.0 ,x2 =   1.0 ,y =  0.6341
# Current weights:
# neuron  0 : w0 =  0.06 , w1 =  0.28 , w2 =  0.43
# neuron  1 : w0 =  0.05 , w1 = -0.24 , w2 =  0.07
# neuron  2 : w0 =  0.08 , w1 =  0.85 , w2 =  0.71
# ----------------
# Current weights:
# neuron  0 : w0 =  0.07 , w1 =  0.28 , w2 =  0.44
# neuron  1 : w0 =  0.06 , w1 = -0.23 , w2 =  0.07
# neuron  2 : w0 =  0.09 , w1 =  0.86 , w2 =  0.71
# ----------------
# Current weights:
# neuron  0 : w0 =  0.08 , w1 =  0.29 , w2 =  0.43
# neuron  1 : w0 =  0.07 , w1 = -0.22 , w2 =  0.07
# neuron  2 : w0 =  0.10 , w1 =  0.86 , w2 =  0.71
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4446
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4751
# x1 =  1.0 ,x2 =   1.0 ,y =  0.6473
# Current weights:
# neuron  0 : w0 =  0.08 , w1 =  0.29 , w2 =  0.43
# neuron  1 : w0 =  0.07 , w1 = -0.22 , w2 =  0.07
# neuron  2 : w0 =  0.11 , w1 =  0.86 , w2 =  0.71
# ----------------
# Current weights:
# neuron  0 : w0 =  0.08 , w1 =  0.30 , w2 =  0.44
# neuron  1 : w0 =  0.07 , w1 = -0.21 , w2 =  0.08
# neuron  2 : w0 =  0.10 , w1 =  0.87 , w2 =  0.70
# ----------------
# Current weights:
# neuron  0 : w0 =  0.09 , w1 =  0.31 , w2 =  0.43
# neuron  1 : w0 =  0.08 , w1 = -0.20 , w2 =  0.07
# neuron  2 : w0 =  0.11 , w1 =  0.87 , w2 =  0.70
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4405
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.4888
# x1 =  1.0 ,x2 =   1.0 ,y =  0.6597
# Current weights:
# neuron  0 : w0 =  0.10 , w1 =  0.32 , w2 =  0.41
# neuron  1 : w0 =  0.08 , w1 = -0.19 , w2 =  0.06
# neuron  2 : w0 =  0.13 , w1 =  0.87 , w2 =  0.70
# ----------------
# Current weights:
# neuron  0 : w0 =  0.09 , w1 =  0.33 , w2 =  0.42
# neuron  1 : w0 =  0.08 , w1 = -0.19 , w2 =  0.07
# neuron  2 : w0 =  0.11 , w1 =  0.87 , w2 =  0.70
# ----------------
# Current weights:
# neuron  0 : w0 =  0.10 , w1 =  0.33 , w2 =  0.42
# neuron  1 : w0 =  0.08 , w1 = -0.18 , w2 =  0.07
# neuron  2 : w0 =  0.12 , w1 =  0.88 , w2 =  0.69
# ----------------
# x1 = -1.0 ,x2 =  -1.0 ,y =  0.4362
# x1 =  1.0 ,x2 =  -1.0 ,y =  0.5019
# x1 =  1.0 ,x2 =   1.0 ,y =  0.6712
